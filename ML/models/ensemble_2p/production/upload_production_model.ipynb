# %% [markdown]
# ---

# %%
import mlflow
from mlflow.tracking import MlflowClient

client = MlflowClient()
model_uri = "models:/HousePrices_Ensemble/Champion"
mlflow.pyfunc.load_model(model_uri)
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[4], line 6
#       4 client = MlflowClient()
#       5 model_uri = "models:/HousePrices_Ensemble/Champion"
# ----> 6 mlflow.pyfunc.load_model(model_uri)
#
# File /opt/miniconda3/envs/Reto_housing/lib/python3.12/site-packages/mlflow/tracing/provider.py:461, in trace_disabled.<locals>.wrapper(*args, **kwargs)
#     459 try:
#     460     is_func_called = True
# --> 461     result = f(*args, **kwargs)
#     462 finally:
#     463     enable()
#
# File /opt/miniconda3/envs/Reto_housing/lib/python3.12/site-packages/mlflow/pyfunc/__init__.py:1131, in load_model(model_uri, suppress_warnings, dst_path, model_config)
#    1127         entity_list.append(Entity(job=job_entity))
#    1129     lineage_header_info = LineageHeaderInfo(entities=entity_list) if entity_list else None
# -> 1131 local_path = _download_artifact_from_uri(
# ...

# %% [markdown]
# ---
